# %% [markdown]
# # <p style="text-align: center;">**Exercise**</p>

# %% [markdown]
# ## **Aim**:  Write a python code to print the files & directories of specified path of the OS                      In tree format.

# %%
import os
from pathlib import Path

# %%
space =  '    '
branch = '│   '
# pointers:
tee =    '├── '
last =   '└── '

# %%
def tree(dir_path: Path, prefix: str=''):
    contents = list(dir_path.iterdir())
    pointers = [tee] * (len(contents) - 1) + [last]
    for pointer, path in zip(pointers, contents):
        yield prefix + pointer + path.name
        if path.is_dir():
            extension = branch if pointer == tee else space 
            yield from tree(path, prefix=prefix+extension)

# %%
for line in tree(Path(r'C:\Users\james\Downloads\python lab')):
    print(line)
# Out:
# ├── .ipynb_checkpoints
# ├── extra
# │   ├── .ipynb_checkpoints
# │   │   └── clustering-checkpoint.ipynb
# │   └── clustering.ipynb
# ├── lab 1 mapping environment
# │   ├── EXPERIMENT 01.docx
# │   ├── lab1.pdf
# │   └── scrneensrt
# │       ├── Anaconda Prompt (Anaconda3) - conda  install pip 23-01-2020 11_22_18.png
# │       ├── Anaconda Prompt (Anaconda3) - conda  install pip 24-01-2020 16_27_12.png
# │       ├── Anaconda Prompt (Anaconda3) - jupyter  notebook 23-01-2020 14_34_09.png
# │       ├── Anaconda Prompt (Anaconda3) 23-01-2020 11_03_01.png
# │       ├── Anaconda Prompt (Anaconda3) 23-01-2020 11_04_02.png
# │       ├── Anaconda Prompt (Anaconda3) 23-01-2020 11_07_14.png
# │       ├── Anaconda Prompt (Anaconda3) 23-01-2020 11_12_14.png
# │       ├── Anaconda Prompt (Anaconda3) 23-01-2020 11_15_05.png
# │       ├── gs 23-01-2020 11_19_59.png
# │       └── gsenv - Notepad 23-01-2020 11_15_20.png
# ├── Lab 10 Socket Programming
# ├── Lab 11 Scapy
# ├── Lab 12 Error and Execptiions
# ├── Lab 13 log file analysis
# ├── Lab 14 Ethical Hacking in Python
# ├── lab 2 LIST
# │   ├── .ipynb_checkpoints
# │   │   ├── 04 LIST Introduction-checkpoint-checkpoint.ipynb
# │   │   └── lab2-checkpoint.ipynb
# │   ├── 04 LIST Introduction-checkpoint.ipynb
# │   ├── lab2.ipynb
# │   └── lab2.pdf
# ├── Lab 3 flow control
# │   ├── .ipynb_checkpoints
# │   │   ├── lab3-checkpoint.ipynb
# │   │   └── Python+Flow+Control-checkpoint.ipynb
# │   ├── lab3.ipynb
# │   ├── lab3.pdf
# │   ├── programmes.txt
# │   └── Python+Flow+Control.ipynb
# ├── Lab 4 dictionary
# │   ├── .ipynb_checkpoints
# │   │   └── Lab4-checkpoint.ipynb
# │   ├── Lab4.ipynb
# │   └── Lab4.pdf
# ├── Lab 5 os module
# │   ├── .ipynb_checkpoints
# │   │   ├── os module-checkpoint.ipynb
# │   │   └── Untitled-checkpoint.ipynb
# │   ├── lab5_1.pdf
# │   ├── os module.ipynb
# │   └── Untitled.ipynb
# ├── lab 6 Tuples
# │   ├── .ipynb_checkpoints
# │   │   └── tuples-checkpoint.ipynb
# │   ├── lab 6.pdf
# │   └── tuples.ipynb
# ├── Lab 7 Functions
# ├── Lab 8 reguler Expression
# │   ├── .ipynb_checkpoints
# │   │   └── lab 7-checkpoint.ipynb
# │   └── lab 7.ipynb
# ├── Lab 9 class and Objects
# └── pthyon
#     ├── .ipynb_checkpoints
#     │   └── practice mst 1-checkpoint.ipynb
#     ├── comp3321.pdf
#     ├── IMG_20200304_212050.jpg
#     ├── IMG_20200304_212115.jpg
#     ├── Lec01
#     │   ├── .ipynb_checkpoints
#     │   │   ├── Introduction to Jupyter Notebook-checkpoint.ipynb
#     │   │   └── satwinder sir py  list tuples-checkpoint.ipynb
#     │   ├── 02 Managing python environments.pptx
#     │   ├── Introduction to Jupyter Notebook.ipynb
#     │   ├── satwinder sir py  list tuples.ipynb
#     │   └── smaple.py
#     ├── lec02
#     │   ├── .ipynb_checkpoints
#     │   │   └── 01 Introduction to Jupyter Notebook-checkpoint.ipynb
#     │   └── 01 Introduction to Jupyter Notebook.ipynb
#     ├── lec03
#     │   ├── .ipynb_checkpoints
#     │   │   └── 04 LIST Introduction-checkpoint.ipynb
#     │   ├── 04 LIST Introduction-checkpoint.ipynb
#     │   └── 04 LIST Introduction.ipynb
#     ├── lec04
#     │   ├── .ipynb_checkpoints
#     │   │   └── Python+Flow+Control-checkpoint.ipynb
#     │   └── Python+Flow+Control.ipynb
#     ├── lec05
#     │   ├── .ipynb_checkpoints
#     │   │   ├── 08 Python Functions-checkpoint.ipynb
#     │   │   └── Python Dicitionary-checkpoint.ipynb
#     │   ├── 08 Python Functions.ipynb
#     │   └── Python Dicitionary.ipynb
#     ├── lec06
#     │   ├── .ipynb_checkpoints
#     │   │   └── os+module-checkpoint.ipynb
#     │   ├── mydir
#     │   ├── os+module.ipynb
#     │   └── python
#     │       └── project1
#     │           └── temp
#     ├── lec07
#     │   ├── .ipynb_checkpoints
#     │   │   └── Regular Expressions Part-1-checkpoint.ipynb
#     │   └── Regular Expressions Part-1.ipynb
#     ├── lec08
#     │   ├── 01-Errors and Exceptions Handling.ipynb
#     │   ├── 02-Errors and Exceptions Homework.ipynb
#     │   ├── 03-Errors and Exceptions Homework - Solution.ipynb
#     │   └── Network Scanning using python-nmap.ipynb
#     ├── lec09
#     │   ├── 17+classes+and+objects+think+python+.ipynb
#     │   ├── Socket Programming in Python.docx
#     │   ├── socket programming python code.pdf
#     │   ├── socket programming python.pdf
#     │   └── Socket Programming.py
#     ├── lec10
#     │   ├── Regular Expressions Part-1.ipynb
#     │   └── Regular Expressions.ipynb
#     ├── lec11
#     │   ├── How to Build an ARP Spoofer in Python using Scapy.pdf
#     │   ├── intro of scapy.pdf
#     │   ├── Network Scanning using scapy.pdf
#     │   └── scapy.ipynb
#     ├── lec12
#     │   ├── Python Multithreading .ipynb
#     │   ├── Socket Programming with Multi-threading in Python.pdf
#     │   └── what is  Multi-Threading.pdf
#     ├── lec13
#     │   ├── Extract-Information-from-Log-files-using-Python-master.zip
#     │   ├── grow-forensic-tools-taxonomy-python-libraries-helpful-forensic-analysis-33453.pdf
#     │   ├── Log file Parsing in Python.pdf
#     │   └── Using Python Pandas for Log Analysis.pdf
#     ├── lec14
#     │   ├── beutiful soup.pdf
#     │   └── python request.pdf
#     ├── lec15
#     │   ├── Windows Registry Forensics.docx
#     │   └── wordd registry forensics.pdf
#     ├── mst1 topics.docx
#     └── practice mst 1.ipynb
